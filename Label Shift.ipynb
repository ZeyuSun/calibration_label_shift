# %%
from uncertainties import ufloat

from simulation_data import GaussianMixtureData
from simulation_label_shift import LabelShiftSimulation
# %load_ext autoreload
# %autoreload 2

# %%
sim = LabelShiftSimulation()
df_long = sim.run()
df_long
# Out:
#      nt   pt  i       method metric     value
# 0   100  0.1  0       source    cal  0.011956
# 1   100  0.1  0       source    sha  0.002052
# 2   100  0.1  0       source    ref  0.009283
# 3   100  0.1  0       source   risk  0.014008
# 4   100  0.1  0       source     bs  0.023291
# 5   100  0.1  0       target    cal  0.000073
# 6   100  0.1  0       target    sha  0.052427
# 7   100  0.1  0       target    ref  0.009283
# 8   100  0.1  0       target   risk  0.052500
# 9   100  0.1  0       target     bs  0.061783
# 10  100  0.1  0  label shift    cal  0.024069
# 11  100  0.1  0  label shift    sha  0.000000
# 12  100  0.1  0  label shift    ref  0.009283
# 13  100  0.1  0  label shift   risk  0.024069
# 14  100  0.1  0  label shift     bs  0.033352
# 15  100  0.1  0    composite    cal  0.000004
# 16  100  0.1  0    composite    sha  0.002052
# 17  100  0.1  0    composite    ref  0.009283
# 18  100  0.1  0    composite   risk  0.002056
# ...

# %%
print(sim.tabulate(df_long, to_latex=True))
sim.tabulate(df_long)
# Out:
# \begin{tabular}{cccccc}
# \toprule
# Method & Estimator & $\REL$ & $\GRP$ & $R$ & MSE \\
# \midrule
# \Source{} & $\hat{h}_P$ & 0.014$ \pm $0.007 & 0.0024$ \pm $0.0007 & 0.017$ \pm $0.007 & 0.026$ \pm $0.007 \\
# \Target{} & $\hat{h}_Q^{\textrm{target}}$ & 0.0008$ \pm $0.0013 & 0.0541$ \pm $0.0033 & 0.055$ \pm $0.005 & 0.064$ \pm $0.005 \\
# \Labelshift{} & $\hat{g}$ & 0.028$ \pm $0.005 & \bfseries 0 & 0.028$ \pm $0.005 & 0.037$ \pm $0.005 \\
# \Composite{} & $\hat{h}_{Q}$ & \bfseries 0.00018$ \pm $0.00029 & 0.0024$ \pm $0.0007 & \bfseries 0.0026$ \pm $0.0006 & \bfseries 0.0119$ \pm $0.0006 \\
# \bottomrule
# \end{tabular}
#                            cal              sha             risk  \
# Method
# source           0.014+/-0.007  0.0024+/-0.0007    0.017+/-0.007
# target         0.0008+/-0.0013  0.0541+/-0.0033    0.055+/-0.005
# label shift      0.028+/-0.005                0    0.028+/-0.005
# composite    0.00018+/-0.00029  0.0024+/-0.0007  0.0026+/-0.0006
#
# ...

# %%
sim.plot()

# %%
df = sim.tabulate(df_long)
print(df.rename(columns={'cal': '$R^{cal}$', 'sha': '$R^{sha}$', 'risk': '$R$', 'bs': 'MSE'}).to_markdown())
# Out:
# | Method      | $R^{cal}$         | $R^{sha}$       | $R$             | MSE             |
# |:------------|:------------------|:----------------|:----------------|:----------------|
# | source      | 0.014+/-0.007     | 0.0024+/-0.0007 | 0.017+/-0.007   | 0.026+/-0.007   |
# | target      | 0.0008+/-0.0013   | 0.0541+/-0.0033 | 0.055+/-0.005   | 0.064+/-0.005   |
# | label shift | 0.028+/-0.005     | 0               | 0.028+/-0.005   | 0.037+/-0.005   |
# | composite   | 0.00018+/-0.00029 | 0.0024+/-0.0007 | 0.0026+/-0.0006 | 0.0119+/-0.0006 |
